# %%
code = 400

# %%
match code:
    case 200:
        print("Ok")
    case 400:
        print("bad Response")
    case 404:
        print("not Foound")
    case _:
        print("Nothing Mtched")
print("End of program ")
# Out:
# bad Response
# End of program
