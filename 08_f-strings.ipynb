# %%
s="Deepchandra"

# %%
s[0]
# Out:
# 'D'

# %%
s.upper()
# Out:
# 'DEEPCHANDRA'

# %%
s
# Out:
# 'Deepchandra'

# %%
#foramte()
name="Deep"
age=21
print("my name is {} and i am {} years of old ".format(name,age))
# Out:
# my name is Deep and i am 21 years of old

# %%
#f-string

print(f"My name is {name} and i am {age} years of old .")
# Out:
# My name is Deep and i am 21 years of old .

# %%
pi=3.14159
print(f"pi reduced to two decimal place:{pi:.2f}")
# Out:
# pi reduced to two decimal place:3.14

# %%
print(f"{'python':<10}")
# Out:
# python

# %%
print(f"{'python':<10}") # left align
print(f"{'python':>10}") # right align
print(f"{'python':^10}") # center align
# Out:
# python
#     python
#   python
