# %%
d={}
type(d)
# Out:
# dict

# %%
# dictinary with key value pair 

student={
    "name" : "Deep",
    "age" : 21,
    "grade" : "A"
}

# %%
student["name"]
# Out:
# 'Deep'

# %%
r=student.get("age")

# %%
print(r)
# Out:
# 21

# %%
student={
    "name" : "Deep",
    "age" : 21,
    "grade" : "A"
}

# %%
print(student["age"])
# Out:
# 21

# %%
student["age"]=30

# %%
student
# Out:
# {'name': 'Deep', 'age': 30, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Deep', 30, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Deep'), ('age', 30), ('grade', 'A')])

# %%
student.update({"name":"bhavna","langvage":"pyhton","num":"9407536951"})

# %%
student
# Out:
# {'name': 'bhavna',
#  'age': 30,
#  'grade': 'A',
#  'langvage': 'pyhton',
#  'num': '9407536951'}

# %%
student.pop("num")
# Out:
# '9407536951'

# %%
student
# Out:
# {'name': 'bhavna', 'age': 30, 'grade': 'A', 'langvage': 'pyhton'}

# %%
student.popitem()
# Out:
# ('langvage', 'pyhton')

# %%
student
# Out:
# {'name': 'bhavna', 'age': 30, 'grade': 'A'}

# %%
r=student.setdefault("name")

# %%
print(r)
# Out:
# bhavna

# %%
student
# Out:
# {'name': 'bhavna', 'age': 30, 'grade': 'A'}

# %%
c=student.copy()

# %%
c
# Out:
# {'name': 'bhavna', 'age': 30, 'grade': 'A'}

# %%
s={
    "name" : "Deep",
    "age" : 21,
    "grade" : "A"
}

# adding a new key value pair 
s["num"]=8103

# updating a exiting value
s["age"]=20

s.pop("name")

print(s)
# Out:
# {'age': 20, 'grade': 'A', 'num': 8103}

# %%
# iteraint over a divtionary

for key,val in s.items():
    print(key,":",val)
# Out:
# age : 20
# grade : A
# num : 8103

# %%
# using dict() constructor

person=dict(name="deep",age=27,city="gwl")
person
# Out:
# {'name': 'deep', 'age': 27, 'city': 'gwl'}

# %%
s={x:x**2 for x in range (1,6)}

# %%
s
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
