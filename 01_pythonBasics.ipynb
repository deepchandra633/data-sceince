# %%
a=5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
name="Deep"

# %%
print("hello",name)
# Out:
# hello Deep

# %%
# this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("harry"))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a="456"

# %%
b="6677"

# %%
print(a+b)
# Out:
# '4566677'

# %%
print(int(a) + int(b))
# Out:
# 7133
