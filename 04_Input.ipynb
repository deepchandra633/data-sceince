# %%
a=input("Enter the value of a ")  # by deafult user taks  input as string
# Out:
# Enter the value of a  10

# %%
a
# Out:
# '10'

# %%
b=input("Enter the value of b ")
# Out:
# Enter the value of b  20

# %%
b
# Out:
# '20'

# %%
a+b
# Out:
# '1020'

# %%
int(a) + int(b)
# Out:
# 30

# %%
c=input()
# Out:
#  65

# %%
c
# Out:
# '65'
