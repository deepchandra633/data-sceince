# %%
a=400

# %%
if (a>53):
    print("greater")
else:
    print("smaller")
# Out:
# greater

# %%
a=33

if a>50:
    print("greater than 50 ")
elif a>40:
    print("greater than 40 ")
elif a>30:
    print("greater than 30 ")
else:
    print("Done ! ")
# Out:
# greater than 30

# %%
def avg(a,b=10):
    return (a+b)/2

# %%
avg(4,6)
# Out:
# 5.0

# %%
avg(4)
# Out:
# 7.0

# %%
def greet():
    print("hello goog morning " )

# %%
greet()
# Out:
# hello goog morning
