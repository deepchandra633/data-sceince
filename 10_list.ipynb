# %%
l=[3,23,5,3]
l[1]
# Out:
# 23

# %%
l[0]=4

# %%
l
# Out:
# [4, 23, 5, 3]

# %%
l.append(9)

# %%
l
# Out:
# [4, 23, 5, 3, 9]

# %%
l2=[10,14]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 23, 5, 3, 9, 10, 14]

# %%
l.insert(0,100)

# %%
l
# Out:
# [100, 4, 23, 5, 3, 9, 10, 14]

# %%
num=l.pop(4)

# %%
num
# Out:
# 3

# %%
l
# Out:
# [100, 4, 23, 5, 9, 10, 14]

# %%
l.index(10)
# Out:
# 5

# %%
l.append(4)

# %%
l
# Out:
# [100, 4, 23, 5, 9, 10, 14, 4]

# %%
l.count(4)
# Out:
# 2

# %%
l.sort() # changes and sorts the original list in ascending order

# %%
l
# Out:
# [4, 4, 5, 9, 10, 14, 23, 100]

# %%
sorted(l)
# Out:
# [4, 4, 5, 9, 10, 14, 23, 100]

# %%
newl=[2,7,4,9,1]

# %%
sorted(newl) # sort the list but do not change the original list
# Out:
# [1, 2, 4, 7, 9]

# %%
newl
# Out:
# [2, 7, 4, 9, 1]

# %%
y=[1,2,3,True ,False,[6,7]]
y
# Out:
# [1, 2, 3, True, False, [6, 7]]

# %%
y[5]
# Out:
# [6, 7]

# %%
y[5][0]
# Out:
# 6

# %%
list1 =[1,2,3,4]
list2=[5,6,7,8]

# %%
list1+list2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list1
# Out:
# [1, 2, 3, 4]

# %%
list2
# Out:
# [5, 6, 7, 8]

# %%
if 3 in list1:
    print("yes")
# Out:
# yes

# %%
3 in list1
# Out:
# True

# %%
6 in list2
# Out:
# True

# %%
s="jack-jill-shubham-kirti-javed-salman-akshay"

# %%
s.split("-")
# Out:
# ['jack', 'jill', 'shubham', 'kirti', 'javed', 'salman', 'akshay']
