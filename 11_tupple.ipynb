# %%
e=()

# %%
type(e)
# Out:
# tuple

# %%
l=[]
type(l)
# Out:
# list

# %%
t=(1,2,3,4,5)
t
# Out:
# (1, 2, 3, 4, 5)

# %%
len(t)
# Out:
# 5

# %%
t[1]
# Out:
# 2

# %%
# packing

person=("deep",21,"Engineer")

# unpacking
name,age,profesion=person
print(name)
print(age)
# Out:
# deep
# 21
