# %%
name="Deepchandra"

# %%
name
# Out:
# 'Deepchandra'

# %%
name.upper()
# Out:
# 'DEEPCHANDRA'

# %%
name.endswith("p")
# Out:
# False

# %%
name.endswith("pp")
# Out:
# False

# %%
name.lower()
# Out:
# 'deepchandra'

# %%
name.count("e")
# Out:
# 2

# %%
name.count("p")
# Out:
# 1

# %%
name[0:4]
# Out:
# 'Deep'

# %%
name[1:-1]
# Out:
# 'eepchandr'

# %%
len(name)
# Out:
# 11

# %%
name[-11:-1]
# Out:
# 'Deepchandr'

# %%
name[0:10]
# Out:
# 'Deepchandr'
