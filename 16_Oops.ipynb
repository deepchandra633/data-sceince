# %%
class Emp:
    comp="HP"
    def __init__(self,name,sal):
        self.name=name
        self.sal=sal
        
    def printDetails(self):
        print(f"The Company of {self.name} is {self.comp} with salary ${self.sal}")
e=Emp("Deepchandra",1200)
e.printDetails()
# Out:
# The Company of Deepchandra is HP with salary $1200

# %%
class Emp:
    comp="HP"
    def __init__(self,name,sal):
        self.name=name
        self.sal=sal
        
    def printDetails(self):
        print(f"The Company of {self.name} is {self.comp} with salary ${self.sal}")

    @staticmethod
    def printTime():
        print(f"the time is now")
    @classmethod
    def printClassDetails(cls):
        print(f"the company is {cls.comp}")
e=Emp("Deepchandra",1200)
e.printDetails()
e.printTime()
e.printClassDetails()
# Out:
# The Company of Deepchandra is HP with salary $1200
# the time is now
# the company is HP
