# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 10

# %%
a = 45 
b = 4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b1=True
b2=False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a=45

# %%
a+=4

# %%
a
# Out:
# 49

# %%
a=45

# %%
a-=4

# %%
a
# Out:
# 41

# %%
a//=5

# %%
a
# Out:
# 8
