# %%
a={}
type(a)
# Out:
# dict

# %%
b=set()
type(b)
# Out:
# set

# %%
s={1,2,3,4,5,6,1,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
list=set([1,2,3,4,5])
print(list)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,5,8,3,9}
s.add(10)

# %%
s
# Out:
# {1, 3, 5, 8, 9, 10}

# %%
s.update([20,30,40,71])

# %%
s
# Out:
# {1, 3, 5, 8, 9, 10, 20, 30, 40, 71}

# %%
num=s.pop()

# %%
num
# Out:
# 1

# %%
s
# Out:
# {3, 5, 8, 9, 10, 20, 30, 40, 71}

# %%
set1={1,2,3,4}
set2={3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
sub={1,3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True

# %%
set1.difference(set2)
# Out:
# {1, 2}

# %%
set2.difference(set1)
# Out:
# {5, 6}

# %%
set1-set2
# Out:
# {1, 2}

# %%
set1^set2
# Out:
# {1, 2, 5, 6}

# %%
set2^set1
# Out:
# {1, 2, 5, 6}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 5, 6}
